# %%
import pandas as pd

# %%
reviews = pd.read_csv('../dataset/reviews_onkel.csv')

# %%
reviews.head()
# Out:
#                nama                                             review
# 0            ekov_3  Awalnya penasaran deket hotel kuk ramai sekali...
# 1        Siba Waihi  Kopi & snack nya enak, tersedia makanan berat,...
# 2    Alvia Fadliana  Tempatnya sangat nyaman, tenang, relax.\nsy or...
# 3  aisah ulfah Syam  Temptnya bagus makanan enak & ada live musikny...
# 4   Muhammad Ikhsan  Saya pesan mie kuah tom yam, enak dan segar. T...

# %%
reviews.shape
# Out:
# (194, 2)

# %%
reviews['review'].isna().sum()
# Out:
# np.int64(66)

# %%
reviews.shape[0] - reviews['review'].isna().sum()
# Out:
# np.int64(128)

# %%
reviews.dropna(inplace=True)

# %%
reviews.shape
# Out:
# (128, 2)

# %%
reviews
# Out:
#                     nama                                             review
# 0                 ekov_3  Awalnya penasaran deket hotel kuk ramai sekali...
# 1             Siba Waihi  Kopi & snack nya enak, tersedia makanan berat,...
# 2         Alvia Fadliana  Tempatnya sangat nyaman, tenang, relax.\nsy or...
# 3       aisah ulfah Syam  Temptnya bagus makanan enak & ada live musikny...
# 4        Muhammad Ikhsan  Saya pesan mie kuah tom yam, enak dan segar. T...
# ..                   ...                                                ...
# 124        Jilian Savary  Superb cafe in the city center. Great atmosphe...
# 125  Anwar Jimpe Rachman  Those who smoke and can do it indoors, this pl...
# 126    Elisabeth Dessaux  A warm and welcoming place, like a second home...
# 133             Sui Yeng                                          Perfect!!
# 135            Juan Nita                                             Forget
#
# [128 rows x 2 columns]

# %%
reviews.to_csv("../dataset/reviews_onkel_clean",index=False)
